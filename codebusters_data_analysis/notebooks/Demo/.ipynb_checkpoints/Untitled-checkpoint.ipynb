# %%
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt

# %% [markdown]
# **Data import**

# %%
tickets = pd.read_csv('i_FAO JIRA 2022-12-05T15_24_20+0100.csv')
tickets.head()
# Out:
#                                              Summary Issue key  Issue id  \
# 0  CEPSA - Not working for Attachement validation...   CI-7816    432641
# 1        ARD / hide sections in regards to EXD-17008   CI-7813    432591
# 2  ADR / add valdiation rule for private overnigh...   CI-7809    432581
# 3      Amadeus - not working on "PreferredApprovers"   CI-7808    432567
# 4                 Numiga GBO - Adapt the Export file   CI-7807    432492
#
#          Issue Type     Status Project key Project name Project type  \
# 0  Expense Delivery     Review          CI  codebusters     software
# 1  Expense Delivery  Configure          CI  codebusters     software
# 2  Expense Delivery     Review          CI  codebusters     software
# 3  Expense Delivery     Review          CI  codebusters     software
# 4  Expense Delivery     Review          CI  codebusters     software
#
#   Project lead  Project description  ...  Comment.17 Comment.18  Comment.19  \
# 0      rohkamm                  NaN  ...         NaN        NaN         NaN
# 1      rohkamm                  NaN  ...         NaN        NaN         NaN
# 2      rohkamm                  NaN  ...         NaN        NaN         NaN
# 3      rohkamm                  NaN  ...         NaN        NaN         NaN
# 4      rohkamm                  NaN  ...         NaN        NaN         NaN
#
#   Comment.20 Comment.21 Comment.22 Comment.23 Comment.24 Comment.25 Comment.26
# 0        NaN        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN        NaN
#
# [5 rows x 248 columns]

# %% [markdown]
# **Define funtions used in the project**

# %%
def convert_to_date(date_string):
    month_and_num = {'Sep': '09', 'Oct':'10', 'Nov':'11', 'Dec': '12'}
    for key, val in month_and_num.items():
        if key in date_string:
            print('found: ', key)
            date_string.replace(key, val)

# %% [markdown]
# ## Data investigation

# %%
tickets['Created'].head()
# Out:
# 0    05/Dec/22 10:09 AM
# 1     05/Dec/22 9:26 AM
# 2     05/Dec/22 9:12 AM
# 3     05/Dec/22 8:05 AM
# 4     03/Dec/22 1:20 PM
# Name: Created, dtype: object

# %%
tickets['Resolved'].head(20)
# Out:
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# 5                    NaN
# 6                    NaN
# 7                    NaN
# 8                    NaN
# 9                    NaN
# 10                   NaN
# 11                   NaN
# 12                   NaN
# 13                   NaN
# 14                   NaN
# 15                   NaN
# 16                   NaN
# 17    02/Dec/22 10:50 AM
# 18     01/Dec/22 2:33 PM
# 19                   NaN
# Name: Resolved, dtype: object

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# Changing column names to more readable format

# %%
ticktes_updated = tickets[['Issue key', 'Status', 'Reporter', 'Created', 'Due Date', 'Resolved', 'Custom field (Customer/s)','Custom field (Type of Request)']]
ticktes_updated.rename({"Custom field (Customer/s)": "Customer", "Custom field (Type of Request)":"Type of Request"},axis=1, inplace=True)

ticktes_updated.info()
ticktes_updated.head(-40)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420 entries, 0 to 419
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Issue key        420 non-null    object
#  1   Status           420 non-null    object
#  2   Reporter         420 non-null    object
#  3   Created          420 non-null    object
#  4   Due Date         420 non-null    object
#  5   Resolved         248 non-null    object
#  6   Customer         420 non-null    object
#  7   Type of Request  420 non-null    object
# dtypes: object(8)
# memory usage: 26.4+ KB
# C:\Users\gmalarski\AppData\Local\Temp\ipykernel_25896\4286452309.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticktes_updated.rename({"Custom field (Customer/s)": "Customer", "Custom field (Type of Request)":"Type of Request"},axis=1, inplace=True)
#     Issue key       Status        Reporter             Created  \
# 0     CI-7816       Review          yutaka  05/Dec/22 10:09 AM
# 1     CI-7813    Configure         mueller   05/Dec/22 9:26 AM
# 2     CI-7809       Review         mueller   05/Dec/22 9:12 AM
# 3     CI-7808       Review          yutaka   05/Dec/22 8:05 AM
# 4     CI-7807       Review     aruizrobles   03/Dec/22 1:20 PM
# ..        ...          ...             ...                 ...
# 375   CI-7415       Closed     aruizrobles  15/Sep/22 10:03 AM
# 376   CI-7414       Closed         mueller   15/Sep/22 9:56 AM
# 377   CI-7413  Communicate  achattopadhyay   15/Sep/22 9:47 AM
# 378   CI-7412  Communicate  achattopadhyay   15/Sep/22 9:40 AM
# 379   CI-7411  Communicate  achattopadhyay   15/Sep/22 9:33 AM
#
#                Due Date           Resolved  Customer        Type of Request
# 0    09/Dec/22 12:00 AM                NaN     CEPSA  Incident Request (IR)
# 1    09/Dec/22 12:00 AM                NaN   ARD.ZDF                Project
# 2    07/Dec/22 12:00 AM                NaN   ARD.ZDF                Project
# 3    09/Dec/22 12:00 AM                NaN   Amadeus  Incident Request (IR)
# 4    15/Dec/22 12:00 AM                NaN    Numiga   Service Request (SR)
# ..                  ...                ...       ...                    ...
# 375  22/Sep/22 12:00 AM  22/Sep/22 5:52 PM    Numiga   Service Request (SR)
# 376  28/Oct/22 12:00 AM  04/Nov/22 8:01 AM   ARD.ZDF                Project
# 377  20/Sep/22 12:00 AM                NaN  Vaillant   Service Request (SR)
# 378  20/Sep/22 12:00 AM                NaN  Vaillant   Service Request (SR)
# 379  20/Sep/22 12:00 AM                NaN  Vaillant   Service Request (SR)
#
# [380 rows x 8 columns]

# %% [markdown]
# ### Date column cleaning

# %% [markdown]
# Convert date columns from string `to datetime` class

# %%
ticktes_updated['Created'] = pd.to_datetime(ticktes_updated['Created'])
ticktes_updated['Due Date'] = pd.to_datetime(ticktes_updated['Due Date'])
ticktes_updated['Resolved'] = pd.to_datetime(ticktes_updated['Resolved'])
ticktes_updated.head(100)
# Out:
# C:\Users\gmalarski\AppData\Local\Temp\ipykernel_25896\1543218348.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticktes_updated['Created'] = pd.to_datetime(ticktes_updated['Created'])
# C:\Users\gmalarski\AppData\Local\Temp\ipykernel_25896\1543218348.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticktes_updated['Due Date'] = pd.to_datetime(ticktes_updated['Due Date'])
# C:\Users\gmalarski\AppData\Local\Temp\ipykernel_25896\1543218348.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticktes_updated['Resolved'] = pd.to_datetime(ticktes_updated['Resolved'])
#    Issue key     Status     Reporter             Created   Due Date  \
# 0    CI-7816     Review       yutaka 2022-12-05 10:09:00 2022-12-09
# 1    CI-7813  Configure      mueller 2022-12-05 09:26:00 2022-12-09
# 2    CI-7809     Review      mueller 2022-12-05 09:12:00 2022-12-07
# 3    CI-7808     Review       yutaka 2022-12-05 08:05:00 2022-12-09
# 4    CI-7807     Review  aruizrobles 2022-12-03 13:20:00 2022-12-15
# ..       ...        ...          ...                 ...        ...
# 95   CI-7708     Closed     nsanchez 2022-11-16 14:47:00 2022-11-23
# 96   CI-7707  Configure     nsanchez 2022-11-16 13:45:00 2022-11-23
# 97   CI-7706  Configure        ssanz 2022-11-16 11:36:00 2022-11-23
# 98   CI-7705     Closed      ccasper 2022-11-16 08:44:00 2022-11-18
# 99   CI-7704     Closed      ccasper 2022-11-16 08:38:00 2022-11-18
#
#               Resolved           Customer        Type of Request
# 0                  NaT              CEPSA  Incident Request (IR)
# 1                  NaT            ARD.ZDF                Project
# 2                  NaT            ARD.ZDF                Project
# 3                  NaT            Amadeus  Incident Request (IR)
# 4                  NaT             Numiga   Service Request (SR)
# ..                 ...                ...                    ...
# 95 2022-12-01 12:38:00            Porsche   Service Request (SR)
# 96                 NaT            Porsche   Service Request (SR)
# 97                 NaT            Allianz  Incident Request (IR)
# 98 2022-11-22 11:27:00  dm-drogerie markt                Project
# 99 2022-11-18 15:50:00  dm-drogerie markt                Project
#
# [100 rows x 8 columns]

# %% [markdown]
# ### Adding `Ticket age` and `Above due date` columns

# %%
ticktes_updated['Ticket age'] = ticktes_updated['Resolved'] - ticktes_updated['Created']
ticktes_updated['Above due date'] = ticktes_updated['Resolved'] - ticktes_updated['Due Date']
ticktes_updated.head(50)
# Out:
# C:\Users\gmalarski\AppData\Local\Temp\ipykernel_25896\3016114884.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticktes_updated['Ticket age'] = ticktes_updated['Resolved'] - ticktes_updated['Created']
# C:\Users\gmalarski\AppData\Local\Temp\ipykernel_25896\3016114884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticktes_updated['Above due date'] = ticktes_updated['Resolved'] - ticktes_updated['Due Date']
#    Issue key                Status        Reporter             Created  \
# 0    CI-7816                Review          yutaka 2022-12-05 10:09:00
# 1    CI-7813             Configure         mueller 2022-12-05 09:26:00
# 2    CI-7809                Review         mueller 2022-12-05 09:12:00
# 3    CI-7808                Review          yutaka 2022-12-05 08:05:00
# 4    CI-7807                Review     aruizrobles 2022-12-03 13:20:00
# 5    CI-7806                Review     aruizrobles 2022-12-02 16:36:00
# 6    CI-7805                Review        hausmann 2022-12-02 15:19:00
# 7    CI-7804                Review   tsteinhaeuser 2022-12-02 14:07:00
# 8    CI-7803                Review        nsanchez 2022-12-02 11:39:00
# 9    CI-7802                Review         mueller 2022-12-02 09:35:00
# 10   CI-7801                Review         mueller 2022-12-02 09:14:00
# 11   CI-7800                Review         mueller 2022-12-02 09:02:00
# 12   CI-7799                Review         mueller 2022-12-02 08:35:00
# 13   CI-7797                Review         mueller 2022-12-02 08:07:00
# 14   CI-7796                Verify     aruizrobles 2022-12-01 18:44:00
# 15   CI-7795                Review        nsanchez 2022-12-01 13:05:00
# 16   CI-7794        Import to Test          skarja 2022-12-01 12:38:00
# 17   CI-7793                Closed        nsanchez 2022-12-01 11:55:00
# 18   CI-7792                Closed           ssanz 2022-12-01 11:33:00
# 19   CI-7791           Communicate        hausmann 2022-12-01 10:37:00
# 20   CI-7790           Communicate        hausmann 2022-12-01 10:34:00
# 21   CI-7789  Import in Production          yutaka 2022-12-01 05:06:00
# 22   CI-7788                Review          yutaka 2022-12-01 01:54:00
# 23   CI-7787                Review           ssanz 2022-11-30 16:24:00
# 24   CI-7786                Review        nsanchez 2022-11-30 15:21:00
# 25   CI-7785                Review        nsanchez 2022-11-30 15:09:00
# 26   CI-7784                Closed        nsanchez 2022-11-30 14:59:00
# 27   CI-7783                Review        nsanchez 2022-11-30 14:39:00
# 28   CI-7782                Review        nsanchez 2022-11-30 13:21:00
# 29   CI-7781                Closed           ssanz 2022-11-30 12:48:00
# 30   CI-7780                Closed  achattopadhyay 2022-11-30 12:25:00
# 31   CI-7779                Review        nsanchez 2022-11-30 10:24:00
# 32   CI-7778                Review        nsanchez 2022-11-30 10:14:00
# 33   CI-7777             Configure          yutaka 2022-11-30 08:04:00
# 34   CI-7776        Import to Test          yutaka 2022-11-30 06:00:00
# 35   CI-7774                Review     aruizrobles 2022-11-28 17:19:00
# 36   CI-7773        Import to Test     aruizrobles 2022-11-28 16:58:00
# 37   CI-7772                Review     aruizrobles 2022-11-28 16:24:00
# 38   CI-7771                Review         ccasper 2022-11-28 16:22:00
# 39   CI-7770                Review           ssanz 2022-11-28 15:59:00
# 40   CI-7769                Review         ccasper 2022-11-28 12:30:00
# 41   CI-7768                Closed         ccasper 2022-11-28 08:57:00
# 42   CI-7767             Configure        nsanchez 2022-11-25 12:26:00
# 43   CI-7766                Review         mueller 2022-11-25 12:12:00
# 44   CI-7765             Configure  achattopadhyay 2022-11-25 12:05:00
# 45   CI-7764  Import in Production          yutaka 2022-11-25 11:26:00
# 46   CI-7763           Communicate        nsanchez 2022-11-25 11:09:00
# 47   CI-7762  Import in Production         shimizu 2022-11-25 10:42:00
# 48   CI-7761                Closed     aruizrobles 2022-11-24 18:08:00
# 49   CI-7760             Configure  achattopadhyay 2022-11-24 13:31:00
#
#      Due Date            Resolved                 Customer  \
# 0  2022-12-09                 NaT                    CEPSA
# 1  2022-12-09                 NaT                  ARD.ZDF
# 2  2022-12-07                 NaT                  ARD.ZDF
# 3  2022-12-09                 NaT                  Amadeus
# 4  2022-12-15                 NaT                   Numiga
# 5  2022-12-12                 NaT                   Numiga
# 6  2022-12-05                 NaT  Customer not yet listed
# 7  2022-12-09                 NaT      Expense Development
# 8  2022-12-02                 NaT                   Orange
# 9  2022-12-09                 NaT                  ARD.ZDF
# 10 2022-12-08                 NaT                  ARD.ZDF
# 11 2022-12-06                 NaT                  ARD.ZDF
# 12 2022-12-07                 NaT                  ARD.ZDF
# 13 2022-12-07                 NaT                  ARD.ZDF
# 14 2022-12-08                 NaT                   Numiga
# 15 2022-12-15                 NaT                  Amadeus
# 16 2022-12-08                 NaT         Deutschlandradio
# 17 2022-12-02 2022-12-02 10:50:00           Endress Hauser
# 18 2022-12-08 2022-12-01 14:33:00                  Allianz
# 19 2022-12-02                 NaT                  Amadeus
# 20 2022-12-02                 NaT                    Burda
# 21 2022-12-08                 NaT                    Ineos
# 22 2022-12-08                 NaT                  Amadeus
# 23 2022-12-06                 NaT                  Allianz
# 24 2022-12-08                 NaT                  Amadeus
# 25 2022-12-01                 NaT           Endress Hauser
# 26 2022-12-01 2022-12-01 08:32:00          Daimler (MFTBC)
# 27 2022-12-12                 NaT         Deutschlandradio
# 28 2022-12-12                 NaT                    Sacyr
# 29 2022-12-07 2022-11-30 16:25:00                  Allianz
# 30 2022-11-30 2022-12-02 15:24:00               Holtzbrink
# 31 2022-12-08                 NaT                  Porsche
# 32 2022-12-08                 NaT         Deutschlandradio
# 33 2022-11-30                 NaT                  ProcurX
# 34 2022-12-05                 NaT                  Amadeus
# 35 2022-12-14                 NaT    Lufthansa City Center
# 36 2023-01-01                 NaT                   Numiga
# 37 2022-12-12                 NaT    Lufthansa City Center
# 38 2022-12-02                 NaT        dm-drogerie markt
# 39 2022-12-05                 NaT                  Allianz
# 40 2022-11-30                 NaT        dm-drogerie markt
# 41 2022-11-30 2022-12-01 09:29:00        dm-drogerie markt
# 42 2022-12-01                 NaT                  Porsche
# 43 2022-11-30                 NaT                  ARD.ZDF
# 44 2022-11-30                 NaT                 Vaillant
# 45 2022-11-29                 NaT                    MFTBC
# 46 2022-11-30                 NaT                  Bentley
# 47 2022-11-30                 NaT       Product Management
# 48 2022-11-29 2022-11-28 15:37:00  Amadeus Pre Sales Demos
# 49 2022-11-29                 NaT        Heidelberg Cement
#
#           Type of Request      Ticket age    Above due date
# 0   Incident Request (IR)             NaT               NaT
# 1                 Project             NaT               NaT
# 2                 Project             NaT               NaT
# 3   Incident Request (IR)             NaT               NaT
# 4    Service Request (SR)             NaT               NaT
# 5    Service Request (SR)             NaT               NaT
# 6   Incident Request (IR)             NaT               NaT
# 7    Service Request (SR)             NaT               NaT
# 8    Service Request (SR)             NaT               NaT
# 9                 Project             NaT               NaT
# 10                Project             NaT               NaT
# 11                Project             NaT               NaT
# 12                Project             NaT               NaT
# 13                Project             NaT               NaT
# 14   Service Request (SR)             NaT               NaT
# 15   Service Request (SR)             NaT               NaT
# 16   Service Request (SR)             NaT               NaT
# 17  Incident Request (IR) 0 days 22:55:00   0 days 10:50:00
# 18  Incident Request (IR) 0 days 03:00:00 -7 days +14:33:00
# 19  Incident Request (IR)             NaT               NaT
# 20  Incident Request (IR)             NaT               NaT
# 21   Service Request (SR)             NaT               NaT
# 22   Service Request (SR)             NaT               NaT
# 23  Incident Request (IR)             NaT               NaT
# 24  Incident Request (IR)             NaT               NaT
# 25   Service Request (SR)             NaT               NaT
# 26   Service Request (SR) 0 days 17:33:00   0 days 08:32:00
# 27   Service Request (SR)             NaT               NaT
# 28   Service Request (SR)             NaT               NaT
# 29   Service Request (SR) 0 days 03:37:00 -7 days +16:25:00
# 30  Incident Request (IR) 2 days 02:59:00   2 days 15:24:00
# 31  Incident Request (IR)             NaT               NaT
# 32   Service Request (SR)             NaT               NaT
# 33   Service Request (SR)             NaT               NaT
# 34   Service Request (SR)             NaT               NaT
# 35   Service Request (SR)             NaT               NaT
# 36   Service Request (SR)             NaT               NaT
# 37   Service Request (SR)             NaT               NaT
# 38                Project             NaT               NaT
# 39   Service Request (SR)             NaT               NaT
# 40                Project             NaT               NaT
# 41                Project 3 days 00:32:00   1 days 09:29:00
# 42   Service Request (SR)             NaT               NaT
# 43                Project             NaT               NaT
# 44   Service Request (SR)             NaT               NaT
# 45   Service Request (SR)             NaT               NaT
# 46   Service Request (SR)             NaT               NaT
# 47   Service Request (SR)             NaT               NaT
# 48   Service Request (SR) 3 days 21:29:00 -1 days +15:37:00
# 49   Service Request (SR)             NaT               NaT

# %% [markdown]
# ## Data analysis

# %% [markdown]
# Number of tickets reported base on type of requests

# %%
# ticktes_updated['Type of Request'].value_counts().plot(kind='pie',  figsize=(7, 7))
type_of_requests_created = ticktes_updated['Type of Request'].value_counts()
explode = (0, 0.1, 0, 0)
fig1, ax1 = plt.subplots(figsize=(7, 7))
ax1.pie(type_of_requests_created, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
ticktes_updated['Type of Request'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Average time to solve each type of the ticket

# %% [markdown]
# SRs open vs closed

# %% [markdown]
# IRs open vs closed

# %% [markdown]
# IRs per customer

# %% [markdown]
# Srs per customer

# %% [markdown]
# MTTR - tickets solved before the due date
